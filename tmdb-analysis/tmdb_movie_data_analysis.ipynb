# %% [markdown]
# # TMDB Movie Data Analysis

# %% [markdown]
# ## Step 1: Fetching Raw Movie Data from the TMDB API
#
# The raw movie data is fetched using The Movie Database (TMDB) API.
# The helper function defined in the `data_fetcher.py` is used for fecthing the day.

# %%
pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\j\anaconda3\envs\creating_an_environment\lib\site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

api_key = os.getenv("TMDB_API_KEY")

# %%
print("API KEY:", os.getenv("TMDB_API_KEY"))
# Out:
# API KEY: 356d9ae6fc108307ae1b5f6358da93ee

# %%
# System setup to access external Python scripts
import sys
import os

sys.path.append(os.path.abspath('../scripts'))
import pandas as pd

# Import fetching function
from tmdb_analysis import fetch_tmdb_data

# Define API parameters
api_key = os.getenv("TMDB_API_KEY")
movie_ids = [0, 299534, 19995, 140607, 299536, 597, 135397, 420818, 24428, 168259, 99861, 284054, 12445, 181808, 330457, 351286, 109445, 321612, 260513]

# Fetch raw data
df_raw = fetch_tmdb_data(movie_ids, api_key)

# Preview first few rows of the dataset
df_raw.head()
# Out:
# Failed to fetch movie with ID: 0
#    adult                     backdrop_path  \
# 0  False  /7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg
# 1  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg
# 2  False  /k6EOrckWFuz7I4z4wiRwz8zsj4H.jpg
# 3  False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg
# 4  False  /sCzcYW9h55WcesOqA12cgEr9Exw.jpg
#
#                                belongs_to_collection     budget  \
# 0  {'id': 86311, 'name': 'The Avengers Collection...  356000000
# 1  {'id': 87096, 'name': 'Avatar Collection', 'po...  237000000
# 2  {'id': 10, 'name': 'Star Wars Collection', 'po...  245000000
# 3  {'id': 86311, 'name': 'The Avengers Collection...  300000000
# 4                                               None  200000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 3  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                             homepage      id    imdb_id  \
# 0     https://www.marvel.com/movies/avengers-endgame  299534  tt4154796
# 1               https://www.avatar.com/movies/avatar   19995  tt0499549
# 2  http://www.starwars.com/films/star-wars-episod...  140607  tt2488496
# 3  https://www.marvel.com/movies/avengers-infinit...  299536  tt4154756
# 4     https://www.paramountmovies.com/movies/titanic     597  tt0120338
#
#   origin_country original_language  ...     revenue runtime  \
# 0           [US]                en  ...  2799439100     181
# 1           [US]                en  ...  2923706026     162
# 2           [US]                en  ...  2068223624     136
# 3           [US]                en  ...  2052415039     149
# 4           [US]                en  ...  2264162353     194
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                      tagline                         title  \
# 0                         Avenge the fallen.             Avengers: Endgame
# 1                Enter the world of Pandora.                        Avatar
# 2              Every generation has a story.  Star Wars: The Force Awakens
# 3              Destiny arrives all the same.        Avengers: Infinity War
# 4  Nothing on Earth could come between them.                       Titanic
#
#    video  vote_average  vote_count  \
# 0  False         8.238       26328
# 1  False         7.589       32226
# 2  False         7.261       19732
# 3  False         8.236       30517
# 4  False         7.906       25979
#
#                                              credits
# 0  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 1  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 2  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 3  {'cast': [{'adult': False, 'gender': 2, 'id': ...
# 4  {'cast': [{'adult': False, 'gender': 2, 'id': ...
#
# [5 rows x 27 columns]

# %%
print("Expected:", len(movie_ids))
print("Fetched:", len(df_raw))
# Out:
# Expected: 19
# Fetched: 18

# %%
df_raw.to_csv("data/raw_movies.csv", index=False)

# %%
# df_raw.to_csv(r"C:\Users\j\OneDrive\Desktop\Data_Engineer_Amalitech\LABS\tmdb-analysis\data\raw_movies.csv", index=False)

# %% [markdown]
# # Step 2: Data Cleaning and Preprocessing

# %%
# Import all data cleaning utilities
from tmdb_analysis import (
    parse_credits_column, extract_cast_crew_info, drop_irrelevant_columns,
    extract_all_fields, convert_column_datatypes, replace_unrealistic_values,
    convert_to_million, adjust_vote_average_by_genre, replace_placeholders,
    drop_duplicates_and_missing_ids_titles, drop_sparse_rows, filter_released_movies,
    reorder_columns, reset_dataframe_index
)

# %%
# Make a copy of the raw data to clean
df_clean = df_raw.copy()

# %%
# Handle 'credits' column
df_clean = parse_credits_column(df_clean)
df_cast_crew = df_clean['credits'].apply(extract_cast_crew_info)
df_clean = pd.concat([df_clean, df_cast_crew], axis=1)

# %%
# Drop unnecessary columns
columns_to_drop = ['credits', 'video', 'adult', 'homepage', 'imdb_id', 'original_title', 'backdrop_path']
df_clean = drop_irrelevant_columns(df_clean, columns_to_drop)

# %%
# Extract relevant fields from JSON columns
df_clean = extract_all_fields(df_clean)

# %%
# Convert column data types
df_clean = convert_column_datatypes(df_clean)

# %%
# Handle unrealistic numeric values
df_clean = replace_unrealistic_values(df_clean)
# Out:
# c:\Users\j\OneDrive\Desktop\Data_Engineer_Amalitech\LABS\tmdb-analysis\tmdb_analysis.py:155: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['budget'].replace(0, np.nan, inplace=True)
# c:\Users\j\OneDrive\Desktop\Data_Engineer_Amalitech\LABS\tmdb-analysis\tmdb_analysis.py:156: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['revenue'].replace(0, np.nan, inplace=True)
# c:\Users\j\OneDrive\Desktop\Data_Engineer_Amalitech\LABS\tmdb-analysis\tmdb_analysis.py:157: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['runtime'].replace(0, np.nan, inplace=True)

# %%
# Convert budget & revenue to millions
df_clean = convert_to_million(df_clean)

# %%
# Adjust vote_average for movies with vote_count == 0 
df_clean = adjust_vote_average_by_genre(df_clean)

# %%
# Replace placeholder texts with NaN
df_clean = replace_placeholders(df_clean)

# %%
# Drop duplicates and missing ids/titles
df_clean = drop_duplicates_and_missing_ids_titles(df_clean)

# %%
# Drop sparse rows with too many missing values 
df_clean = drop_sparse_rows(df_clean, min_non_null=10)

# %%
# Keep only released movies
df_clean = filter_released_movies(df_clean)

# %%
# Reorder columns for final dataset
df_clean = reorder_columns(df_clean)

# %%
# Reset index 
df_clean = reset_dataframe_index(df_clean)

# %%
df_clean.head()
# Out:
#       id                                         title  \
# 0    597                                       Titanic
# 1  12445  Harry Potter and the Deathly Hallows: Part 2
# 2  19995                                        Avatar
# 3  24428                                  The Avengers
# 4  99861                       Avengers: Age of Ultron
#
#                                      tagline release_date           genres  \
# 0  Nothing on Earth could come between them.   1997-11-18            Drama
# 1                               It all ends.   2011-07-12          Fantasy
# 2                Enter the world of Pandora.   2009-12-15           Action
# 3                    Some assembly required.   2012-04-25  Science Fiction
# 4                        A new age has come.   2015-04-22           Action
#
#      belongs_to_collection original_language  budget_musd  revenue_musd  \
# 0                     None                en        200.0   2264.162353
# 1  Harry Potter Collection                en        125.0   1341.511219
# 2        Avatar Collection                en        237.0   2923.706026
# 3  The Avengers Collection                en        220.0   1518.815515
# 4  The Avengers Collection                en        365.0   1405.403694
#
#                                 production_companies  ... vote_average  \
# 0  Paramount Pictures|20th Century Fox|Lightstorm...  ...        7.906
# 1                 Warner Bros. Pictures|Heyday Films  ...        8.087
# 2  Dune Entertainment|Lightstorm Entertainment|20...  ...        7.589
# 3                                     Marvel Studios  ...        7.747
# 4                                     Marvel Studios  ...        7.271
#
#    popularity  runtime                                           overview  \
# 0     31.6671      194  101-year-old Rose DeWitt Bukater tells the sto...
# 1     19.0149      130  Harry, Ron and Hermione continue their quest t...
# 2     25.0266      162  In the 22nd century, a paraplegic Marine is di...
# 3     30.4445      143  When an unexpected enemy emerges and threatens...
# 4     15.8466      141  When Tony Stark tries to jumpstart a dormant p...
#
#                                 spoken_languages  \
# 0  English|French|German|Swedish|Italian|Russian
# 1                                        English
# 2                                English|Spanish
# 3                          English|Hindi|Russian
# 4                                        English
#
#                         poster_path  \
# 0  /9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg
# 1  /c54HpQmuwXjHq2C9wmoACjxoom3.jpg
# 2  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 3   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
# 4  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg
#
#                                                 cast cast_size       director  \
# 0  Leonardo DiCaprio|Kate Winslet|Billy Zane|Kath...       116  James Cameron
# 1  Daniel Radcliffe|Emma Watson|Rupert Grint|Ralp...       104    David Yates
# 2  Sam Worthington|Zoe Saldaña|Sigourney Weaver|S...        65  James Cameron
# 3  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...       112    Joss Whedon
# 4  Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...        72    Joss Whedon
#
#    crew_size
# 0        260
# 1        156
# 2        987
# 3        632
# 4        640
#
# [5 rows x 22 columns]

# %%
df_clean.to_csv("data/clean_movies.csv", index=False)

# %% [markdown]
# # Step 3: KPI Implementation & Analysis

# %%
# Load the cleaned dataset
df_clean = pd.read_csv("data/clean_movies.csv")

# %%
from tmdb_analysis import (
    calculate_profit, calculate_roi, kpi_ranking, filter_movies,
    franchise_vs_standalone, most_successful_franchises, most_successful_directors
)

# %%
# Calculate KPI Rankings
kpi_results = kpi_ranking(df_clean)
print("KPI Rankings:", kpi_results)
# Out:
# KPI Rankings: {'Highest Revenue':       id   title                      tagline release_date  genres  \
# 2  19995  Avatar  Enter the world of Pandora.   2009-12-15  Action
#
#   belongs_to_collection original_language  budget_musd  revenue_musd  \
# 2     Avatar Collection                en        237.0   2923.706026
#
#                                 production_companies  ... runtime  \
# 2  Dune Entertainment|Lightstorm Entertainment|20...  ...     162
#
#                                             overview  spoken_languages  \
# 2  In the 22nd century, a paraplegic Marine is di...   English|Spanish
#
#                         poster_path  \
# 2  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
#
#                                                 cast cast_size       director  \
# 2  Sam Worthington|Zoe Saldaña|Sigourney Weaver|S...        65  James Cameron
#
#   crew_size       profit   roi
# 2       987  2686.706026  None
#
# [1 rows x 24 columns], 'Highest Budget':       id                    title              tagline release_date  genres  \
# 4  99861  Avengers: Age of Ultron  A new age has come.   2015-04-22  Action
#
#      belongs_to_collection original_language  budget_musd  revenue_musd  \
# 4  The Avengers Collection                en        365.0   1405.403694
#
#   production_companies  ... runtime  \
# 4       Marvel Studios  ...     141
#
#                                             overview  spoken_languages  \
# 4  When Tony Stark tries to jumpstart a dormant p...           English
#
#                         poster_path  \
# 4  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg
#
#                                                 cast cast_size     director  \
# 4  Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...        72  Joss Whedon
#
#   crew_size       profit   roi
# 4       640  1040.403694  None
#
# [1 rows x 24 columns], 'Highest Profit':       id   title                      tagline release_date  genres  \
# 2  19995  Avatar  Enter the world of Pandora.   2009-12-15  Action
#
#   belongs_to_collection original_language  budget_musd  revenue_musd  \
# 2     Avatar Collection                en        237.0   2923.706026
#
#                                 production_companies  ... runtime  \
# 2  Dune Entertainment|Lightstorm Entertainment|20...  ...     162
#
#                                             overview  spoken_languages  \
# 2  In the 22nd century, a paraplegic Marine is di...   English|Spanish
#
#                         poster_path  \
# 2  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
#
#                                                 cast cast_size       director  \
# 2  Sam Worthington|Zoe Saldaña|Sigourney Weaver|S...        65  James Cameron
#
#   crew_size       profit   roi
# 2       987  2686.706026  None
#
# [1 rows x 24 columns], 'Lowest Profit':       id                    title              tagline release_date  genres  \
# 4  99861  Avengers: Age of Ultron  A new age has come.   2015-04-22  Action
#
#      belongs_to_collection original_language  budget_musd  revenue_musd  \
# 4  The Avengers Collection                en        365.0   1405.403694
#
#   production_companies  ... runtime  \
# 4       Marvel Studios  ...     141
#
#                                             overview  spoken_languages  \
# 4  When Tony Stark tries to jumpstart a dormant p...           English
#
#                         poster_path  \
# 4  /4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg
#
#                                                 cast cast_size     director  \
# 4  Robert Downey Jr.|Chris Hemsworth|Mark Ruffalo...        72  Joss Whedon
#
#   crew_size       profit   roi
# 4       640  1040.403694  None
#
# [1 rows x 24 columns], 'Highest ROI': Empty DataFrame
# Columns: [id, title, tagline, release_date, genres, belongs_to_collection, original_language, budget_musd, revenue_musd, production_companies, production_countries, vote_count, vote_average, popularity, runtime, overview, spoken_languages, poster_path, cast, cast_size, director, crew_size, profit, roi]
# Index: []
#
# [0 rows x 24 columns], 'Lowest ROI': Empty DataFrame
# Columns: [id, title, tagline, release_date, genres, belongs_to_collection, original_language, budget_musd, revenue_musd, production_companies, production_countries, vote_count, vote_average, popularity, runtime, overview, spoken_languages, poster_path, cast, cast_size, director, crew_size, profit, roi]
# Index: []
#
# [0 rows x 24 columns], 'Most Voted':       id   title                      tagline release_date  genres  \
# 2  19995  Avatar  Enter the world of Pandora.   2009-12-15  Action
#
#   belongs_to_collection original_language  budget_musd  revenue_musd  \
# 2     Avatar Collection                en        237.0   2923.706026
#
#                                 production_companies  ... runtime  \
# 2  Dune Entertainment|Lightstorm Entertainment|20...  ...     162
#
#                                             overview  spoken_languages  \
# 2  In the 22nd century, a paraplegic Marine is di...   English|Spanish
#
#                         poster_path  \
# 2  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
#
#                                                 cast cast_size       director  \
# 2  Sam Worthington|Zoe Saldaña|Sigourney Weaver|S...        65  James Cameron
#
#   crew_size       profit   roi
# 2       987  2686.706026  None
#
# [1 rows x 24 columns], 'Highest Rated':         id              title             tagline release_date     genres  \
# 12  299534  Avengers: Endgame  Avenge the fallen.   2019-04-24  Adventure
#
#       belongs_to_collection original_language  budget_musd  revenue_musd  \
# 12  The Avengers Collection                en        356.0     2799.4391
#
#    production_companies  ... runtime  \
# 12       Marvel Studios  ...     181
#
#                                              overview        spoken_languages  \
# 12  After the devastating events of Avengers: Infi...  English|Japanese|Xhosa
#
#                          poster_path  \
# 12  /ulzhLuWrPK07P1YkdWQLZnQh1JL.jpg
#
#                                                  cast cast_size  \
# 12  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...       105
#
#          director crew_size     profit   roi
# 12  Anthony Russo       595  2443.4391  None
#
# [1 rows x 24 columns], 'Lowest Rated':         id                           title            tagline release_date  \
# 16  351286  Jurassic World: Fallen Kingdom  The park is gone.   2018-06-06
#
#     genres     belongs_to_collection original_language  budget_musd  \
# 16  Action  Jurassic Park Collection                en        170.0
#
#     revenue_musd                     production_companies  ... runtime  \
# 16   1310.466296  Amblin Entertainment|Universal Pictures  ...     129
#
#                                              overview  spoken_languages  \
# 16  Three years after Jurassic World was destroyed...   English|Russian
#
#                          poster_path  \
# 16  /270MrJNqJovumHXGE6SSt0zwUIF.jpg
#
#                                                  cast cast_size     director  \
# 16  Chris Pratt|Bryce Dallas Howard|Rafe Spall|Jus...        40  J.A. Bayona
#
#    crew_size       profit   roi
# 16       381  1140.466296  None
#
# [1 rows x 24 columns], 'Most Popular':         id                   title                        tagline  \
# 13  299536  Avengers: Infinity War  Destiny arrives all the same.
#
#    release_date     genres    belongs_to_collection original_language  \
# 13   2018-04-25  Adventure  The Avengers Collection                en
#
#     budget_musd  revenue_musd production_companies  ... runtime  \
# 13        300.0   2052.415039       Marvel Studios  ...     149
#
#                                              overview  spoken_languages  \
# 13  As the Avengers and their allies have continue...     English|Xhosa
#
#                          poster_path  \
# 13  /7WsyChQLEftFiDOVTGkv3hFpyyt.jpg
#
#                                                  cast cast_size  \
# 13  Robert Downey Jr.|Chris Evans|Chris Hemsworth|...        69
#
#          director crew_size       profit   roi
# 13  Anthony Russo       723  1752.415039  None
#
# [1 rows x 24 columns]}

# %%
# Search Queries
# Search 1: Find the best-rated Science Fiction Action movies starring Bruce Willis
search_1 = filter_movies(df_clean, genre="Science Fiction|Action", actor="Bruce Willis", sort_by="vote_average")
print("\nBest-rated Science Fiction Action Movies starring Bruce Willis:", search_1)
# Out:
# Best-rated Science Fiction Action Movies starring Bruce Willis: Empty DataFrame
# Columns: [id, title, tagline, release_date, genres, belongs_to_collection, original_language, budget_musd, revenue_musd, production_companies, production_countries, vote_count, vote_average, popularity, runtime, overview, spoken_languages, poster_path, cast, cast_size, director, crew_size, profit, roi]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Search 2: Find movies starring Uma Thurman, directed by Quentin Tarantino
search_2 = filter_movies(df_clean, actor="Uma Thurman", director="Quentin Tarantino", sort_by="runtime")
print("\nMovies starring Uma Thurman, directed by Quentin Tarantino:", search_2)
# Out:
# Movies starring Uma Thurman, directed by Quentin Tarantino: Empty DataFrame
# Columns: [id, title, tagline, release_date, genres, belongs_to_collection, original_language, budget_musd, revenue_musd, production_companies, production_countries, vote_count, vote_average, popularity, runtime, overview, spoken_languages, poster_path, cast, cast_size, director, crew_size, profit, roi]
# Index: []
#
# [0 rows x 24 columns]

# %%
df_clean["is_franchise"] = df_clean["belongs_to_collection"].notna()

# %%
# Franchise vs Standalone Movie Comparison
franchise_stats, standalone_stats = franchise_vs_standalone(df_clean)
print("\nFranchise Movie Stats:", franchise_stats)
print("Standalone Movie Stats:", standalone_stats)
# Out:
# Franchise Movie Stats: {'Mean Revenue': 1682.6419708125, 'Mean Rating': 7.381187499999999, 'Total Movies': 16}
# Standalone Movie Stats: {'Mean Revenue': 1765.1391585000001, 'Mean Rating': 7.439, 'Total Movies': 2}

# %%
# Most Successful Franchises
franchise_success = most_successful_franchises(df_clean)
print("\nMost Successful Movie Franchises:", franchise_success)
# Out:
# Most Successful Movie Franchises:                                      movie_count  total_budget  mean_budget  \
# belongs_to_collection
# The Avengers Collection                        4        1241.0       310.25
# Frozen Collection                              2         300.0       150.00
# Jurassic Park Collection                       2         320.0       160.00
# Star Wars Collection                           2         445.0       222.50
# Avatar Collection                              1         237.0       237.00
# Black Panther Collection                       1         200.0       200.00
# Harry Potter Collection                        1         125.0       125.00
# The Fast and the Furious Collection            1         190.0       190.00
# The Incredibles Collection                     1         200.0       200.00
# The Lion King (Reboot) Collection              1         260.0       260.00
#
#                                      total_revenue  mean_revenue  mean_rating
# belongs_to_collection
# The Avengers Collection                7776.073348   1944.018337       7.8730
# Frozen Collection                      2727.902485   1363.951242       7.2480
# Jurassic Park Collection               2982.003740   1491.001870       6.6165
# Star Wars Collection                   3400.922454   1700.461227       7.0195
# Avatar Collection                      2923.706026   2923.706026       7.5890
# Black Panther Collection               1349.926083   1349.926083       7.3730
# Harry Potter Collection                1341.511219   1341.511219       8.0870
# The Fast and the Furious Collection    1515.400000   1515.400000       7.2250
# The Incredibles Collection             1242.805359   1242.805359       7.4540
# The Lion King (Reboot) Collection      1662.020819   1662.020819       7.1110

# %%
# Most Successful Directors
director_success = most_successful_directors(df_clean)
print("\nMost Successful Directors:", director_success)
# Out:
# Most Successful Directors:                  movie_count  total_revenue  mean_rating
# director
# Anthony Russo              2    4851.854139       8.2370
# James Cameron              2    5187.868379       7.7475
# Jennifer Lee               2    2727.902485       7.2480
# Joss Whedon                2    2924.219209       7.5090
# Bill Condon                1    1266.115964       6.9720
# Brad Bird                  1    1242.805359       7.4540
# Colin Trevorrow            1    1671.537444       6.6950
# David Yates                1    1341.511219       8.0870
# J.A. Bayona                1    1310.466296       6.5380
# J.J. Abrams                1    2068.223624       7.2610
# James Wan                  1    1515.400000       7.2250
# Jon Favreau                1    1662.020819       7.1110
# Rian Johnson               1    1332.698830       6.7780
# Ryan Coogler               1    1349.926083       7.3730

# %% [markdown]
# # Step 4: Data Visualization

# %%
import importlib
import tmdb_analysis
importlib.reload(tmdb_analysis)

from tmdb_analysis import plot_yearly_trends
from tmdb_analysis import plot_roi_distribution_by_genre

# %%
# import all functions needed
from tmdb_analysis import (
    plot_revenue_vs_budget,
    plot_roi_distribution_by_genre,
    plot_popularity_vs_rating,
    plot_yearly_trends,
    plot_franchise_vs_standalone,
)

from tmdb_analysis import convert_to_million

# %%
# Load the clean dataset
df_clean.to_csv("data/clean_movies.csv", index=False)

# %%
from tmdb_analysis import plot_revenue_vs_budget

print("Plotting Revenue vs Budget Trends...")
plot_revenue_vs_budget(df_clean)
# Out:
# Plotting Revenue vs Budget Trends...

# %%
print("Plotting ROI Distribution by Genre...")
plot_roi_distribution_by_genre(df_clean)
# Out:
# Plotting ROI Distribution by Genre...

# %%
# Plot Popularity vs Rating
print("Plotting Popularity vs Rating...")
plot_popularity_vs_rating(df_clean)
# Out:
# Plotting Popularity vs Rating...

# %%
# Plot Yearly Trends in Box Office Performance
print("Plotting Yearly Trends in Box Office Performance...")
plot_yearly_trends(df_clean)
# Out:
# Plotting Yearly Trends in Box Office Performance...

# %%
# Create 'is_franchise' column from 'belongs_to_collection'
df_clean['is_franchise'] = df_clean['belongs_to_collection'].notnull().astype(int)

# %%
# Plot Franchise vs Standalone Success
print("Plotting Franchise vs Standalone Success...")
plot_franchise_vs_standalone(df_clean)
# Out:
# Plotting Franchise vs Standalone Success...
